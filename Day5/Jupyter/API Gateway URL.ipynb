# %% [markdown]
# # API Service Initialization and API Client in Python
#
# ## Introduction
# An API (Application Programming Interface) allows applications to communicate with each other. In this tutorial, we'll explore how to set up an API service using Flask and create an API client using Python's `requests` library.
#
# ## Setting Up an API Service (Flask)
# Flask is a lightweight web framework in Python that makes it easy to create APIs.
#
# ### Install Flask
# To install Flask, run:
# ```sh
# pip install flask
# ```
#
# ### Create a Simple API Service
# Create a file named `api_service.py` and add the following code:
#
# ```python
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
#
# # Sample data
# data = {
#     "message": "Hello, this is a simple API!",
#     "status": "success"
# }
#
# @app.route("/api", methods=["GET"])
# def get_data():
#     return jsonify(data)
#
# if __name__ == "__main__":
#     app.run(host="127.0.0.1", port=5000, debug=True)
# ```
#
# ### Run the API Service
# Start the API service by running:
# ```sh
# python api_service.py
# ```
# Your API will be available at `http://127.0.0.1:5000/api`.
#
# ## Creating an API Client
# We can use Python's `requests` library to interact with the API.
#
# ### Install Requests
# ```sh
# pip install requests
# ```
#
# ### Write an API Client
# Create a file named `api_client.py` and add the following code:
#
# ```python
# import requests
#
# API_URL = "http://127.0.0.1:5000/api"
#
# response = requests.get(API_URL)
#
# if response.status_code == 200:
#     print("Response Data:", response.json())
# else:
#     print("Failed to retrieve data, status code:", response.status_code)
# ```
#
# ### Run the API Client
# ```sh
# python api_client.py
# ```
# You should see the following output:
# ```
# Response Data: {'message': 'Hello, this is a simple API!', 'status': 'success'}
# ```
#
# ## Conclusion
# In this tutorial, we set up a simple API service using Flask and created an API client using Python's `requests` library. This forms the basis of API communication in Python applications.

# %%
import requests

# Define API Gateway URL
api_url = "http://127.0.0.1:5005/v1/devices"

# Make a GET request
response = requests.get(api_url)

# Check if request was successful
if response.status_code == 200:
    data = response.json()  # Convert response to JSON
    print(type(data))
    for device in data:
        print(device)
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# <class 'list'>
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'bc:09:1b:dd:f1:e9', 'IP_Address': '10.1.1.121', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-4', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Cisco UCS-FI-6454', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'bc:09:1b:dd:f1:a0', 'IP_Address': '10.1.1.111', 'Firmware_Version': 'v1.0', 'Software_Version': '4.2(2e)', 'Hardware_Model': 'Cisco UCS-FI-6332-16UP-2', 'Auto_Grp': 'Fabric Interconnect', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Cisco UCS-FI-6454', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'bc:09:1b:dd:f1:a1', 'IP_Address': '10.1.1.112', 'Firmware_Version': 'v1.0', 'Software_Version': '4.2(2e)', 'Hardware_Model': 'Cisco UCS-FI-6332-16UP-3', 'Auto_Grp': 'Fabric Interconnect', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Cisco UCS-FI-6454', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'bc:09:1b:dd:f1:a2', 'IP_Address': '10.1.1.113', 'Firmware_Version': 'v1.0', 'Software_Version': '4.2(2e)', 'Hardware_Model': 'Cisco UCS-FI-6332-16UP-4', 'Auto_Grp': 'Fabric Interconnect', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Cisco UCS-FI-6454', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'bc:09:1b:dd:f1:a3', 'IP_Address': '10.1.1.114', 'Firmware_Version': 'v1.0', 'Software_Version': '4.2(2e)', 'Hardware_Model': 'Cisco UCS-FI-6332-16UP-5', 'Auto_Grp': 'Fabric Interconnect', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Cisco UCS-FI-6454', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'bc:09:1b:dd:f1:a4', 'IP_Address': '10.1.1.115', 'Firmware_Version': 'v1.0', 'Software_Version': '4.2(2e)', 'Hardware_Model': 'Cisco UCS-FI-6332-16UP-6', 'Auto_Grp': 'Fabric Interconnect', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Cisco UCS-FI-6454', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'bc:09:1b:dd:f1:a5', 'IP_Address': '10.1.1.116', 'Firmware_Version': 'v1.0', 'Software_Version': '4.2(2e)', 'Hardware_Model': 'Cisco UCS-FI-6332-16UP-7', 'Auto_Grp': 'Fabric Interconnect', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Cisco UCS-FI-6454', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'bc:09:1b:dd:f1:a6', 'IP_Address': '10.1.1.117', 'Firmware_Version': 'v1.0', 'Software_Version': '4.2(2e)', 'Hardware_Model': 'Cisco UCS-FI-6332-16UP-8', 'Auto_Grp': 'Fabric Interconnect', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'bc:09:1b:dd:f1:a7', 'IP_Address': '10.1.1.118', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-1', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'bc:09:1b:dd:f1:a8', 'IP_Address': '10.1.1.119', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-2', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'bc:09:1b:dd:f1:a9', 'IP_Address': '10.1.1.120', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-3', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'dc:09:1b:dd:f1:a0', 'IP_Address': '10.1.1.122', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-5', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'dc:09:1b:dd:f1:a1', 'IP_Address': '192.168.0.140', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-6', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'dc:09:1b:dd:f1:a2', 'IP_Address': '10.1.1.124', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-7', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'dc:09:1b:dd:f1:a3', 'IP_Address': '10.1.1.125', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-8', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'dc:09:1b:dd:f1:a4', 'IP_Address': '10.1.1.126', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-9', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'dc:09:1b:dd:f1:a5', 'IP_Address': '10.1.1.127', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-10', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'dc:09:1b:dd:f1:a6', 'IP_Address': '10.1.1.128', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-11', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'dc:09:1b:dd:f1:a7', 'IP_Address': '10.1.1.129', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-12', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'dc:09:1b:dd:f1:a8', 'IP_Address': '10.1.1.130', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-13', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'dc:09:1b:dd:f1:a9', 'IP_Address': '192.168.0.140', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-14', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'ec:09:1b:dd:f1:a0', 'IP_Address': '10.1.1.132', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-15', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco N9K-C9336C-FX2', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'ec:09:1b:dd:f1:a1', 'IP_Address': '10.1.1.133', 'Firmware_Version': 'v1.0', 'Software_Version': 'v10.2', 'Hardware_Model': 'cisco Nexus9000 C9336C-FX2-16', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'ec:09:1b:dd:f1:a2', 'IP_Address': '10.1.1.134', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-1', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'ec:09:1b:dd:f1:a3', 'IP_Address': '10.1.1.135', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-2', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'ec:09:1b:dd:f1:a4', 'IP_Address': '10.1.1.136', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-3', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'ec:09:1b:dd:f1:a5', 'IP_Address': '10.1.1.137', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-4', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'ec:09:1b:dd:f1:a6', 'IP_Address': '192.168.0.140', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-5', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'ec:09:1b:dd:f1:a7', 'IP_Address': '192.168.0.140', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-6', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'ec:09:1b:dd:f1:a8', 'IP_Address': '192.168.0.140', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-7', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'ec:09:1b:dd:f1:a9', 'IP_Address': '10.1.1.141', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-8', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:09:1b:dd:f1:a1', 'IP_Address': '192.168.0.140', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-9', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:09:1b:dd:f1:a2', 'IP_Address': '10.1.1.143', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-10', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:09:1b:dd:f1:a3', 'IP_Address': '192.168.0.140', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-11', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:09:1b:dd:f1:a4', 'IP_Address': '10.1.1.145', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-12', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:09:1b:dd:f1:a5', 'IP_Address': '10.1.1.146', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-13', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:09:1b:dd:f1:a6', 'IP_Address': '10.1.1.147', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-14', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:09:1b:dd:f1:a7', 'IP_Address': '10.1.1.148', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-15', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:09:1b:dd:f1:a8', 'IP_Address': '10.1.1.149', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-16', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:09:1b:dd:f1:a9', 'IP_Address': '10.1.1.150', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-17', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:10:1b:dd:f1:a1', 'IP_Address': '10.1.1.151', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-18', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:10:1b:dd:f1:a2', 'IP_Address': '10.1.1.152', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-19', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:10:1b:dd:f1:a3', 'IP_Address': '10.1.1.153', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-20', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:10:1b:dd:f1:a4', 'IP_Address': '10.1.1.154', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-21', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:10:1b:dd:f1:a5', 'IP_Address': '10.1.1.155', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-22', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:10:1b:dd:f1:a6', 'IP_Address': '10.1.1.156', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-23', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:10:1b:dd:f1:a7', 'IP_Address': '10.1.1.157', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-24', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:10:1b:dd:f1:a8', 'IP_Address': '10.1.1.158', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-25', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:10:1b:dd:f1:a9', 'IP_Address': '10.1.1.159', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-26', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:11:1b:dd:f1:a0', 'IP_Address': '10.1.1.160', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-27', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:11:1b:dd:f1:a1', 'IP_Address': '10.1.1.161', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-28', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:11:1b:dd:f1:a2', 'IP_Address': '10.1.1.162', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-29', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:11:1b:dd:f1:a3', 'IP_Address': '10.1.1.163', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-30', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:11:1b:dd:f1:a4', 'IP_Address': '10.1.1.164', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-31', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'cisco MDS - tcl', 'Vendor_Name': 'Cisco', 'Hardware_Address': 'fc:11:1b:dd:f1:a5', 'IP_Address': '10.1.1.165', 'Firmware_Version': 'v1.0', 'Software_Version': 'v9.2(2)', 'Hardware_Model': 'cisco cisco MDS - tcl 9396T 96X 32G FC-32', 'Auto_Grp': 'Switch', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:11:1b:dd:f1:a6', 'IP_Address': '10.1.1.166', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-1 ', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:11:1b:dd:f1:a7', 'IP_Address': '10.1.1.167', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-2', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:11:1b:dd:f1:a8', 'IP_Address': '10.1.1.168', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-3', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:11:1b:dd:f1:a9', 'IP_Address': '10.1.1.169', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-4', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:12:1b:dd:f1:a0', 'IP_Address': '10.1.1.170', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-5', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:12:1b:dd:f1:a1', 'IP_Address': '10.1.1.171', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-6', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:12:1b:dd:f1:a2', 'IP_Address': '10.1.1.172', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-7', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:12:1b:dd:f1:a3', 'IP_Address': '10.1.1.173', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-8', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:12:1b:dd:f1:a4', 'IP_Address': '10.1.1.174', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-9', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:12:1b:dd:f1:a5', 'IP_Address': '10.1.1.175', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-10', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:12:1b:dd:f1:a6', 'IP_Address': '10.1.1.176', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-11', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:12:1b:dd:f1:a7', 'IP_Address': '10.1.1.177', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-12', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:12:1b:dd:f1:a8', 'IP_Address': '10.1.1.178', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-13', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:12:1b:dd:f1:a9', 'IP_Address': '10.1.1.179', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-14', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:13:1b:dd:f1:a0', 'IP_Address': '10.1.1.180', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-15', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:13:1b:dd:f1:a1', 'IP_Address': '10.1.1.181', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-16', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:13:1b:dd:f1:a2', 'IP_Address': '10.1.1.182', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-17', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:13:1b:dd:f1:a3', 'IP_Address': '10.1.1.183', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-18', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashArray', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:13:1b:dd:f1:a4', 'IP_Address': '10.1.1.184', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'X10r2-19', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:13:1b:dd:f1:a5', 'IP_Address': '10.1.1.185', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-1', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:13:1b:dd:f1:a6', 'IP_Address': '10.1.1.186', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-2', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:13:1b:dd:f1:a7', 'IP_Address': '10.1.1.187', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-3', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:13:1b:dd:f1:a8', 'IP_Address': '10.1.1.188', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-4', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:13:1b:dd:f1:a9', 'IP_Address': '10.1.1.189', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-5', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:14:1b:dd:f1:a0', 'IP_Address': '10.1.1.190', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-6', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:14:1b:dd:f1:a1', 'IP_Address': '10.1.1.191', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-7', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:14:1b:dd:f1:a2', 'IP_Address': '10.1.1.192', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-8', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:14:1b:dd:f1:a3', 'IP_Address': '10.1.1.193', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-9', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:14:1b:dd:f1:a12', 'IP_Address': '10.1.1.194', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-10', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:14:1b:dd:f1:a11', 'IP_Address': '10.1.1.195', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-11', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:14:1b:dd:f1:a10', 'IP_Address': '10.1.1.196', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-12', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
# {'Inventory_Type': 'Pure Storage | FlashBlade', 'Vendor_Name': 'Pure Storage', 'Hardware_Address': 'fc:14:1b:dd:f1:a9', 'IP_Address': '10.1.1.197', 'Firmware_Version': 'v1.0', 'Software_Version': 'Purity//FA 6.6.10', 'Hardware_Model': 'XFM-8400-13', 'Auto_Grp': 'Storage', 'Tags': None, 'Status': 'Online', 'Discovery_Type': 'Simulated'}
